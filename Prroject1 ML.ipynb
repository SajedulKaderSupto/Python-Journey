# %%
#linear regression withmultiple variable

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\DR. FAHAD\\OneDrive\\Documents\\Book2.csv')

# %%
df
# Out:
#    Speed  Car_age  Experience  Risk
# 0     10       93        20.0    85
# 1    113       12        13.0    20
# 2     60       10         4.0    93
# 3     45        5         NaN    60
# 4    200       20         3.0    82
# 5    115        2         8.0    10

# %%
df.Experience
# Out:
# 0    20.0
# 1    13.0
# 2     4.0
# 3     NaN
# 4     3.0
# 5     8.0
# Name: Experience, dtype: float64

# %%
df.Experience.mean()
# Out:
# 9.6

# %%
mx=df.Experience.median()

# %%
mx
# Out:
# 8.0

# %%
df.Experience=df['Experience'].fillna(mx)

# %%
df.Experience
# Out:
# 0    20.0
# 1    13.0
# 2     4.0
# 3     8.0
# 4     3.0
# 5     8.0
# Name: Experience, dtype: float64

# %%
df
# Out:
#    Speed  Car_age  Experience  Risk
# 0     10       93        20.0    85
# 1    113       12        13.0    20
# 2     60       10         4.0    93
# 3     45        5         8.0    60
# 4    200       20         3.0    82
# 5    115        2         8.0    10

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df[['Speed','Car_age','Experience']],df.Risk)
# Out:
# LinearRegression()

# %%
reg.predict([[160,10,5]])
# Out:
# C:\Users\DR. FAHAD\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([57.68290397])

# %%
reg.coef_
# Out:
# array([-0.24028832,  1.38663567, -8.07699145])

# %%
reg.intercept_
# Out:
# 122.64763540564275
