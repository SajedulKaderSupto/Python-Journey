# %%
# !pip install matplotlib

# %%
# !pip install scikit-learn

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('C:\\Users\\DR. FAHAD\\OneDrive\\Documents\\Book1.csv')

# %%
df
# Out:
#        Date  Starting  Ending
# 0  01.01.24    164100   21324
# 1  01.12.23    133414   12000
# 2  01.10.23    142435   34454
# 3  01.02.23    133333   35430
# 4  01.07.23    122445   14242
# 5  01.02.24     12421  121212
# 6  01.09.22    123453   12114
# 7  01.02.98    112240  112240

# %%
df.head()
# Out:
#        Date  Starting  Ending
# 0  01.01.24    164100   21324
# 1  01.12.23    133414   12000
# 2  01.10.23    142435   34454
# 3  01.02.23    133333   35430
# 4  01.07.23    122445   14242

# %%
df.isnull().sum()
# Out:
# Date        0
# Starting    0
# Ending      0
# dtype: int64

# %%
df.drop('Date',axis=1)
# Out:
#    Starting  Ending
# 0    164100   21324
# 1    133414   12000
# 2    142435   34454
# 3    133333   35430
# 4    122445   14242
# 5     12421  121212
# 6    123453   12114
# 7    112240  112240

# %%
plt.scatter(df['Starting'],df['Ending'])
plt.xlabel('Starting')
plt.ylabel('Ending')
plt.title('NasDaq100 Stock Prixe')
# Out:
# Text(0.5, 1.0, 'NasDaq100 Stock Prixe')

# %%
#LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
x=df.drop('Date',axis=1)

# %%
print(df.columns)
# Out:
# Index(['Date', 'Starting', 'Ending'], dtype='object')

# %%
print(df.columns.tolist())
# Out:
# ['Date', 'Starting', 'Ending']

# %%
df=df.loc[:,~df.columns.str.contains('^Unnamed')]

# %%
df.columns=df.columns.str.strip()
df.columns=df.columns.str.replace(' ','_')

# %%
df=df.drop(df.columns[1],axis=1)

# %%
print(df.columns)
# Out:
# Index(['Date', 'Ending'], dtype='object')

# %%
x.head()
# Out:
#    Starting  Ending
# 0    164100   21324
# 1    133414   12000
# 2    142435   34454
# 3    133333   35430
# 4    122445   14242

# %%
x.mean()
# Out:
# Starting    117980.125
# Ending       45377.000
# dtype: float64

# %%
df=pd.read_csv('C:\\Users\\DR. FAHAD\\OneDrive\\Documents\\Book1.csv')

# %%
df
# Out:
#        Date  Starting  Ending
# 0  01.01.24    164100   21324
# 1  01.12.23    133414   12000
# 2  01.10.23    142435   34454
# 3  01.02.23    133333   35430
# 4  01.07.23    122445   14242
# 5  01.02.24     12421  121212
# 6  01.09.22    123453   12114
# 7  01.02.98    112240  112240

# %%
x=df[['Starting']]
y=df[['Ending']]

# %%
x
# Out:
#    Starting
# 0    164100
# 1    133414
# 2    142435
# 3    133333
# 4    122445
# 5     12421
# 6    123453
# 7    112240

# %%
y
# Out:
#    Ending
# 0   21324
# 1   12000
# 2   34454
# 3   35430
# 4   14242
# 5  121212
# 6   12114
# 7  112240

# %%
x.mean()
# Out:
# Starting    117980.125
# dtype: float64

# %%
y.mean()
# Out:
# Ending    45377.0
# dtype: float64

# %%
plt.scatter(x.mean(),y.mean(),color='red')

plt.scatter(df['Starting'],df['Ending'])
plt.xlabel('Starting')
plt.ylabel('Ending')
plt.title('NasDaq100 Stock Prixe')
# Out:
# Text(0.5, 1.0, 'NasDaq100 Stock Prixe')

# %%
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
m=reg.coef_

# %%
c=reg.intercept_

# %%
#y=mx+c

# %%
m*16700+c
# Out:
# array([[120886.36760596]])

# %%
plt.plot(x,reg.predict(x))

plt.scatter(x.mean(),y.mean(),color='red')

plt.scatter(df['Starting'],df['Ending'])
plt.xlabel('Starting')
plt.ylabel('Ending')
plt.title('NasDaq100 Stock Prixe')
# Out:
# Text(0.5, 1.0, 'NasDaq100 Stock Prixe')

# %%
#Loss and Cost Function

# %%
df['loss']=df['Ending']-df['Starting']

# %%
df.head()
# Out:
#        Date  Starting  Ending    loss
# 0  01.01.24    164100   21324 -142776
# 1  01.12.23    133414   12000 -121414
# 2  01.10.23    142435   34454 -107981
# 3  01.02.23    133333   35430  -97903
# 4  01.07.23    122445   14242 -108203

# %%
#MSE

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
mse=mean_squared_error(df['Starting'],df['Ending'])

# %%
mse   #mean_squred_error
# Out:
# 11538872894.125

# %%
mae=mean_absolute_error(df['Starting'],df['Ending'])

# %%
mae  #mean_absolute_error
# Out:
# 99800.875

# %%
sum(abs(df['loss']))/len(x)
# Out:
# 99800.875

# %%
plt.plot(x,reg.predict(x))

plt.scatter(x.mean(),y.mean(),color='red')

plt.scatter(df['Starting'],df['Ending'])
plt.scatter(df['Starting'],reg.predict(x))
plt.xlabel('Starting')
plt.ylabel('Ending')
plt.title('NasDaq100 Stock Prixe')
# Out:
# Text(0.5, 1.0, 'NasDaq100 Stock Prixe')

# %%
#R@ Squared Value//Accuracy for Regression

# %%
from sklearn.metrics import r2_score

# %%
reg.score(x,y)
# Out:
# 0.5643068927307453

# %%
r2_score(y,reg.predict(x))
# Out:
# 0.5643068927307453

# %%
#thats the beginning of my jouney
#ALLAH plz help me
# 14 December 2024
