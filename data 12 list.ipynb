# %% [markdown]
# List in Python

# %%
li=[2,3,45,67]

# %%
li[0]
# Out:
# 2

# %%
li[-1]
# Out:
# 67

# %%
li[-2]
# Out:
# 45

# %%
li[0:2]
# Out:
# [2, 3]

# %%
li[0]='rt'

# %%
li
# Out:
# ['rt', 3, 45, 67]

# %%
li.append('study marker')

# %%
li
# Out:
# ['rt', 3, 45, 67, 'study marker']

# %%
import sys
sys.getsizeof(li)
# Out:
# 120

# %%
li.pop()
# Out:
# 'study marker'

# %%
li
# Out:
# ['rt', 3, 45, 67]

# %%
li.pop(0)
# Out:
# 'rt'

# %%
li
# Out:
# [3, 45, 67]

# %%
#creqting list
l2 =list(('ai',12,91,(1,2,3,4)))

# %%
l2
# Out:
# ['ai', 12, 91, (1, 2, 3, 4)]

# %%
type(l2)
# Out:
# list

# %%
#input list from user
l3=[]
n =int(input ('enter your total index: '))
for i in range(n):
    new=input()
    l3.append(new)
print(13)
# Out:
# enter your total index:  5
#  1
#  2
#  3
#  4
#  5
# 13
