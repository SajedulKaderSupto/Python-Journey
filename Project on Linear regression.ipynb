# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#importing the dataset
df=pd.read_csv('C:\\Users\\DR. FAHAD\\OneDrive\\Documents\\Company.csv')

# %%
df
# Out:
#     Marketting Spend  Administration  Transport        Area   Profit
# 0             123455            3223        141       Dhaka  1344312
# 1              32974            2134          2  Chittagong  3231453
# 2              34532            5787         41      Khulna    32154
# 3                232           78965         76     Comilla     3452
# 4               2521              87         66        Feni      352
# 5              26543             998       6989    NoaKhali     2135
# 6              65382               7         86     Rangpur    32512
# 7             568534               7         76       Dhaka      233
# 8                 56              34         80    Barishal      325
# 9                383             877          8   Sirajgong     2345
# 10                33               5         65       Dhaka     4233
# 11             34664               5          5      Khulna     2152
# 12             46434               5          6        Feni      231
# ...

# %% [raw]
# SEPARATE X,Y

# %%
df.shape
# Out:
# (25, 5)

# %%
df.isnull().sum()
# Out:
# Marketting Spend    0
# Administration      0
# Transport           0
# Area                0
# Profit              0
# dtype: int64

# %%
x=df.drop(['Profit'],axis=1)

# %%
x
# Out:
#     Marketting Spend  Administration  Transport        Area
# 0             123455            3223        141       Dhaka
# 1              32974            2134          2  Chittagong
# 2              34532            5787         41      Khulna
# 3                232           78965         76     Comilla
# 4               2521              87         66        Feni
# 5              26543             998       6989    NoaKhali
# 6              65382               7         86     Rangpur
# 7             568534               7         76       Dhaka
# 8                 56              34         80    Barishal
# 9                383             877          8   Sirajgong
# 10                33               5         65       Dhaka
# 11             34664               5          5      Khulna
# 12             46434               5          6        Feni
# 13              4643              78         90     Comilla
# 14                 3              90         88    Rajshahi
# ...

# %%
y=df['Profit']

# %%
y
# Out:
# 0     1344312
# 1     3231453
# 2       32154
# 3        3452
# 4         352
# 5        2135
# 6       32512
# 7         233
# 8         325
# 9        2345
# 10       4233
# 11       2152
# 12        231
# 13        568
# 14       8076
# 15     768578
# 16         89
# 17      76575
# 18         85
# 19       7785
# 20        898
# 21        798
# 22          7
# 23          7
# 24       7585
# Name: Profit, dtype: int64

# %%
#ONE HOT ENCODING

# %%
city=pd.get_dummies(x['Area'],drop_first=True)

# %%
city
# Out:
#     Bogura  Chittagong  Comilla  Dhaka   Feni  Khulna  NoaKhali  Rajshahi  \
# 0    False       False    False   True  False   False     False     False
# 1    False        True    False  False  False   False     False     False
# 2    False       False    False  False  False    True     False     False
# 3    False       False     True  False  False   False     False     False
# 4    False       False    False  False   True   False     False     False
# 5    False       False    False  False  False   False      True     False
# 6    False       False    False  False  False   False     False     False
# 7    False       False    False   True  False   False     False     False
# 8    False       False    False  False  False   False     False     False
# 9    False       False    False  False  False   False     False     False
# 10   False       False    False   True  False   False     False     False
# 11   False       False    False  False  False    True     False     False
# ...

# %%
#drop the area column
x=x.drop('Area',axis=1)

# %%
x
# Out:
#     Marketting Spend  Administration  Transport
# 0             123455            3223        141
# 1              32974            2134          2
# 2              34532            5787         41
# 3                232           78965         76
# 4               2521              87         66
# 5              26543             998       6989
# 6              65382               7         86
# 7             568534               7         76
# 8                 56              34         80
# 9                383             877          8
# 10                33               5         65
# 11             34664               5          5
# 12             46434               5          6
# 13              4643              78         90
# 14                 3              90         88
# 15                 3              80         99
# 16             36346              34         55
# 17          32567889              77         33
# 18              3245              67          4
# ...

# %%
x=pd.concat([x,city],axis=1)

# %%
x
# Out:
#     Marketting Spend  Administration  Transport  Bogura  Chittagong  Comilla  \
# 0             123455            3223        141   False       False    False
# 1              32974            2134          2   False        True    False
# 2              34532            5787         41   False       False    False
# 3                232           78965         76   False       False     True
# 4               2521              87         66   False       False    False
# 5              26543             998       6989   False       False    False
# 6              65382               7         86   False       False    False
# 7             568534               7         76   False       False    False
# 8                 56              34         80   False       False    False
# 9                383             877          8   False       False    False
# 10                33               5         65   False       False    False
# ...

# %%
#spitting the dataset into the trainning and test set

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Assuming x and y are already defined and are valid pandas DataFrame or Series
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.25, random_state=0)

# Convert to appropriate formats if needed
xtrain = xtrain.values
ytrain = ytrain.values.ravel()

# Initialize and fit the model
regressor = LinearRegression()
regressor.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
xtest
# Out:
#     Marketting Spend  Administration  Transport  Bogura  Chittagong  Comilla  \
# 5              26543             998       6989   False       False    False
# 2              34532            5787         41   False       False    False
# 19               542              55        234   False       False     True
# 16             36346              34         55   False       False    False
# 11             34664               5          5   False       False    False
# 22          18268982              90        658   False       False    False
# 17          32567889              77         33   False        True    False
#
#     Dhaka   Feni  Khulna  NoaKhali  Rajshahi  Rangpur  Sirajgong
# 5   False  False   False      True     False    False      False
# 2   False  False    True     False     False    False      False
# 19  False  False   False     False     False    False      False
# 16   True  False   False     False     False    False      False
# ...

# %%
#test the result
pred=regressor.predict(xtest)
# Out:
# C:\Users\DR. FAHAD\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
pred
# Out:
# array([ 4.12101905e+04, -1.84168108e+04, -3.93833735e+04,  6.03918820e+05,
#        -2.44346503e+04, -1.39960921e+07, -2.28320848e+07])

# %%
#R SQURED VALUE

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(ytest,pred)

# %%
score
# Out:
# -147777.17934644068

# %%
from sklearn.model_selection import train_test_split

x = df[["Marketting Spend", "Administration", "Transport"]]
y = df["Profit"]

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.25, random_state=0)

# %%
import matplotlib.pyplot as plt
y.hist()
plt.show()

# %%
print(xtrain.describe())
print(xtest.describe())
# Out:
#        Marketting Spend  Administration    Transport
# count         18.000000       18.000000    18.000000
# mean       47113.944444     4807.833333   418.500000
# std       134180.273859    18527.810900  1502.237322
# min            3.000000        0.000000     2.000000
# 25%           38.250000        7.000000    59.750000
# 50%          307.500000       79.000000    76.000000
# 75%        25891.250000      608.000000    87.500000
# max       568534.000000    78965.000000  6436.000000
#        Marketting Spend  Administration    Transport
# count      7.000000e+00        7.000000     7.000000
# mean       7.281357e+06     1006.571429  1145.000000
# std        1.305948e+07     2137.416888  2587.227796
# min        5.420000e+02        5.000000     5.000000
# 25%        3.053750e+04       44.500000    37.000000
# 50%        3.466400e+04       77.000000    55.000000
# 75%        9.152664e+06      544.000000   446.000000
# max        3.256789e+07     5787.000000  6989.000000

# %%
import seaborn as sns
sns.heatmap(x.corr(), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
comparison = pd.DataFrame({"Actual": ytest, "Predicted": pred})
print(comparison)
# Out:
#     Actual     Predicted
# 5     2135  4.121019e+04
# 2    32154 -1.841681e+04
# 19    7785 -3.938337e+04
# 16      89  6.039188e+05
# 11    2152 -2.443465e+04
# 22       7 -1.399609e+07
# 17   76575 -2.283208e+07

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

# Prepare data
features = ["Marketting Spend", "Administration", "Transport"]
target = "Profit"
x = df[features]
y = df[target]

# Split data
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.25, random_state=0)

# Scale features
scaler = StandardScaler()
xtrain_scaled = scaler.fit_transform(xtrain)
xtest_scaled = scaler.transform(xtest)

# Train model
regressor = LinearRegression()
regressor.fit(xtrain_scaled, ytrain)

# Predict
pred = regressor.predict(xtest_scaled)

# Evaluate
score = r2_score(ytest, pred)
print("R^2 Score:", score)
# Out:
# R^2 Score: -100.95687879399043
