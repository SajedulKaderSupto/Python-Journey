# %% [markdown]
# FROZEN SET

# %%
sa={1,23,425,'a','b',(1,2,3,4,5)}

# %%
set1=frozenset(sa)

# %%
type(sa)
# Out:
# set

# %%
sa
# Out:
# {(1, 2, 3, 4, 5), 1, 23, 425, 'a', 'b'}

# %%
set1
# Out:
# frozenset({(1, 2, 3, 4, 5), 1, 23, 425, 'a', 'b'})
