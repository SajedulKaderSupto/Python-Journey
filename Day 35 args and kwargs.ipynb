# %%
#args and kwargs

# %%
def personal_data(name,**arg):
    print(name)
    print(arg)
    print(type(arg))

personal_data('SAJEDUL KADER SUPTO',versity='CoU',city='erlagen')
# Out:
# SAJEDUL KADER SUPTO
# {'versity': 'CoU', 'city': 'erlagen'}
# <class 'dict'>
