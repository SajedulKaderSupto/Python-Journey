# %%
import pandas as pd

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %%
city = ['Comilla','Dhaka','Feni','Chattogram']

# %%
city
# Out:
# ['Comilla', 'Dhaka', 'Feni', 'Chattogram']

# %%
df=pd.DataFrame(city)

# %%
df
# Out:
#             0
# 0     Comilla
# 1       Dhaka
# 2        Feni
# 3  Chattogram

# %%
row,col=df.shape

# %%
row
# Out:
# 4

# %%
col
# Out:
# 1

# %%
df=pd.DataFrame(city,columns=['CITY IN BANGLADESH'])

# %%
df
# Out:
#   CITY IN BANGLADESH
# 0            Comilla
# 1              Dhaka
# 2               Feni
# 3         Chattogram

# %%
df=pd.DataFrame(city,columns=['CITY IN BANGLADESH'],index=['c1','c2','c3','c4'])

# %%
df
# Out:
#    CITY IN BANGLADESH
# c1            Comilla
# c2              Dhaka
# c3               Feni
# c4         Chattogram

# %%
city2=['dortmund','Paris','Potsdam','NewYork']
df2=pd.DataFrame(zip(city,city2),columns=['City','City2'])

# %%
df.shape
# Out:
# (4, 1)

# %%
df
# Out:
#    CITY IN BANGLADESH
# c1            Comilla
# c2              Dhaka
# c3               Feni
# c4         Chattogram

# %%
df2
# Out:
#          City     City2
# 0     Comilla  dortmund
# 1       Dhaka     Paris
# 2        Feni   Potsdam
# 3  Chattogram   NewYork

# %%
df2.shape
# Out:
# (4, 2)

# %%
city3=[['BAVARIA','ERLANGEN'],['NRW','DORTMUND']]

# %%
df3=pd.DataFrame(city3)

# %%
df3
# Out:
#          0         1
# 0  BAVARIA  ERLANGEN
# 1      NRW  DORTMUND

# %%
city
# Out:
# ['Comilla', 'Dhaka', 'Feni', 'Chattogram']

# %%
dic1={

    'city':city,
    'city2':city2

}

# %%
dic1
# Out:
# {'city': ['Comilla', 'Dhaka', 'Feni', 'Chattogram'],
#  'city2': ['dortmund', 'Paris', 'Potsdam', 'NewYork']}

# %%
df5=pd.DataFrame(dic1)

# %%
df5
# Out:
#          city     city2
# 0     Comilla  dortmund
# 1       Dhaka     Paris
# 2        Feni   Potsdam
# 3  Chattogram   NewYork

# %%
type(df5)
# Out:
# pandas.core.frame.DataFrame

# %%
file_path=r'C:\\Users\\DR. FAHAD\\OneDrive\\Documents\\SalesReport1.xlsx'

# %%
df=pd.read_excel('C:\\Users\\DR. FAHAD\\OneDrive\\Documents\\SalesReport1.xlsx')

# %%
df
# Out:
#            Product Customer    Qtr 1  Qtr 2   Qtr 3    Qtr 4
# 0     Alice Mutton    ANTON     0.00  702.0    0.00     0.00
# 1     Alice Mutton    BERGS   312.00    0.0    0.00     0.00
# 2     Alice Mutton    BOLID     0.00    0.0    0.00  1170.00
# 3     Alice Mutton    BOTTM  1170.00    0.0    0.00     0.00
# 4     Alice Mutton    ERNSH  1123.20    0.0    0.00  2607.15
# ..             ...      ...      ...    ...     ...      ...
# 272  Veggie-spread    FOLIG     0.00    0.0    0.00  1317.00
# 273  Veggie-spread    HUNGO   921.37    0.0    0.00     0.00
# 274  Veggie-spread    MORGK     0.00  263.4    0.00     0.00
# 275  Veggie-spread    PICCO     0.00    0.0    0.00   395.10
# 276  Veggie-spread    WHITC     0.00    0.0  842.88     0.00
#
# [277 rows x 6 columns]

# %%
df.head()
# Out:
#         Product Customer   Qtr 1  Qtr 2  Qtr 3    Qtr 4
# 0  Alice Mutton    ANTON     0.0  702.0    0.0     0.00
# 1  Alice Mutton    BERGS   312.0    0.0    0.0     0.00
# 2  Alice Mutton    BOLID     0.0    0.0    0.0  1170.00
# 3  Alice Mutton    BOTTM  1170.0    0.0    0.0     0.00
# 4  Alice Mutton    ERNSH  1123.2    0.0    0.0  2607.15

# %%
df.tail()
# Out:
#            Product Customer   Qtr 1  Qtr 2   Qtr 3   Qtr 4
# 272  Veggie-spread    FOLIG    0.00    0.0    0.00  1317.0
# 273  Veggie-spread    HUNGO  921.37    0.0    0.00     0.0
# 274  Veggie-spread    MORGK    0.00  263.4    0.00     0.0
# 275  Veggie-spread    PICCO    0.00    0.0    0.00   395.1
# 276  Veggie-spread    WHITC    0.00    0.0  842.88     0.0

# %%
df.head(10)
# Out:
#         Product Customer   Qtr 1   Qtr 2  Qtr 3    Qtr 4
# 0  Alice Mutton    ANTON     0.0   702.0    0.0     0.00
# 1  Alice Mutton    BERGS   312.0     0.0    0.0     0.00
# 2  Alice Mutton    BOLID     0.0     0.0    0.0  1170.00
# 3  Alice Mutton    BOTTM  1170.0     0.0    0.0     0.00
# 4  Alice Mutton    ERNSH  1123.2     0.0    0.0  2607.15
# 5  Alice Mutton    GODOS     0.0   280.8    0.0     0.00
# 6  Alice Mutton    HUNGC    62.4     0.0    0.0     0.00
# 7  Alice Mutton    PICCO     0.0  1560.0  936.0     0.00
# 8  Alice Mutton    RATTC     0.0   592.8    0.0     0.00
# 9  Alice Mutton    REGGC     0.0     0.0    0.0   741.00

# %%
df.tail(10)
# Out:
#                              Product Customer    Qtr 1  Qtr 2    Qtr 3   Qtr 4
# 267  Uncle Bob's Organic Dried Pears    SAVEA     0.00    0.0  1350.00     0.0
# 268  Uncle Bob's Organic Dried Pears    VAFFE     0.00    0.0   300.00     0.0
# 269  Uncle Bob's Organic Dried Pears    VICTE   364.80  300.0     0.00     0.0
# 270                    Veggie-spread    ALFKI     0.00    0.0     0.00   878.0
# 271                    Veggie-spread    ERNSH  2281.50    0.0     0.00     0.0
# 272                    Veggie-spread    FOLIG     0.00    0.0     0.00  1317.0
# 273                    Veggie-spread    HUNGO   921.37    0.0     0.00     0.0
# 274                    Veggie-spread    MORGK     0.00  263.4     0.00     0.0
# 275                    Veggie-spread    PICCO     0.00    0.0     0.00   395.1
# 276                    Veggie-spread    WHITC     0.00    0.0   842.88     0.0

# %%
df.values
# Out:
# array([['Alice Mutton', 'ANTON', 0.0, 702.0, 0.0, 0.0],
#        ['Alice Mutton', 'BERGS', 312.0, 0.0, 0.0, 0.0],
#        ['Alice Mutton', 'BOLID', 0.0, 0.0, 0.0, 1170.0],
#        ...,
#        ['Veggie-spread', 'MORGK', 0.0, 263.4, 0.0, 0.0],
#        ['Veggie-spread', 'PICCO', 0.0, 0.0, 0.0, 395.1],
#        ['Veggie-spread', 'WHITC', 0.0, 0.0, 842.88, 0.0]], dtype=object)

# %%
df.columns
# Out:
# Index(['Product', 'Customer', 'Qtr 1', 'Qtr 2', 'Qtr 3', 'Qtr 4'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=277, step=1)

# %%
df.Customer
# Out:
# 0      ANTON
# 1      BERGS
# 2      BOLID
# 3      BOTTM
# 4      ERNSH
#        ...
# 272    FOLIG
# 273    HUNGO
# 274    MORGK
# 275    PICCO
# 276    WHITC
# Name: Customer, Length: 277, dtype: object

# %%
df['Product'].head()
# Out:
# 0    Alice Mutton
# 1    Alice Mutton
# 2    Alice Mutton
# 3    Alice Mutton
# 4    Alice Mutton
# Name: Product, dtype: object

# %%
df[['Product','Customer','Qtr 1']]
# Out:
#            Product Customer    Qtr 1
# 0     Alice Mutton    ANTON     0.00
# 1     Alice Mutton    BERGS   312.00
# 2     Alice Mutton    BOLID     0.00
# 3     Alice Mutton    BOTTM  1170.00
# 4     Alice Mutton    ERNSH  1123.20
# ..             ...      ...      ...
# 272  Veggie-spread    FOLIG     0.00
# 273  Veggie-spread    HUNGO   921.37
# 274  Veggie-spread    MORGK     0.00
# 275  Veggie-spread    PICCO     0.00
# 276  Veggie-spread    WHITC     0.00
#
# [277 rows x 3 columns]

# %%
df['Qtr 3'].sort_values()
# Out:
# 0         0.0
# 161       0.0
# 163       0.0
# 164       0.0
# 165       0.0
#         ...
# 50     1776.5
# 175    2088.0
# 47     2261.0
# 53     2380.0
# 10     3900.0
# Name: Qtr 3, Length: 277, dtype: float64

# %%
df.sort_values('Product')
# Out:
#            Product Customer    Qtr 1  Qtr 2   Qtr 3    Qtr 4
# 0     Alice Mutton    ANTON     0.00  702.0    0.00     0.00
# 1     Alice Mutton    BERGS   312.00    0.0    0.00     0.00
# 2     Alice Mutton    BOLID     0.00    0.0    0.00  1170.00
# 3     Alice Mutton    BOTTM  1170.00    0.0    0.00     0.00
# 4     Alice Mutton    ERNSH  1123.20    0.0    0.00  2607.15
# ..             ...      ...      ...    ...     ...      ...
# 271  Veggie-spread    ERNSH  2281.50    0.0    0.00     0.00
# 272  Veggie-spread    FOLIG     0.00    0.0    0.00  1317.00
# 273  Veggie-spread    HUNGO   921.37    0.0    0.00     0.00
# 274  Veggie-spread    MORGK     0.00  263.4    0.00     0.00
# 276  Veggie-spread    WHITC     0.00    0.0  842.88     0.00
#
# [277 rows x 6 columns]

# %%
df.describe()
# Out:
#              Qtr 1        Qtr 2        Qtr 3        Qtr 4
# count   277.000000   277.000000   277.000000   277.000000
# mean     88.855271   156.805199   150.327581   161.744621
# std     254.991062   389.259507   433.856409   386.840078
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000
# 75%       0.000000    96.500000     0.000000   110.400000
# max    2281.500000  3159.000000  3900.000000  2700.000000

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 2
#       1 import seaborn as sns
# ----> 2 sns.heatmap(df.corr(),annot=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
df['Qtr 1']>50
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 272    False
# 273     True
# 274    False
# 275    False
# 276    False
# Name: Qtr 1, Length: 277, dtype: bool
