# %%
tup1=()

# %%
type(tup1)
# Out:
# tuple

# %%
tup1=('ds',1,2,3,4,5,6,[10,20,30],True,'nstu')

# %%
tup1[-1]
# Out:
# 'nstu'

# %%
tup3=tuple([1,234,3,35])

# %%
tup3
# Out:
# (1, 234, 3, 35)

# %%
tup1+tup3
# Out:
# ('ds', 1, 2, 3, 4, 5, 6, [10, 20, 30], True, 'nstu', 1, 234, 3, 35)

# %%
tup3*4
# Out:
# (1, 234, 3, 35, 1, 234, 3, 35, 1, 234, 3, 35, 1, 234, 3, 35)

# %%
tup3.count(4)
# Out:
# 0

# %%
for i in tup1:
    print(i)
# Out:
# ds
# 1
# 2
# 3
# 4
# 5
# 6
# [10, 20, 30]
# True
# nstu
