# %% [markdown]
# DIctionary

# %%
dic={

    'name':'supto' ,
    'versity':'Comilla University' ,
}

# %%
dic
# Out:
# {'name': 'supto', 'versity': 'Comilla University'}

# %%
dic.keys()
# Out:
# dict_keys(['name', 'versity'])

# %%
type(dic)
# Out:
# dict

# %%
dic.values()
# Out:
# dict_values(['supto', 'Comilla University'])

# %%
#copy
dic2=dic.copy()

# %%
dic['versity']='fau'

# %%
dic
# Out:
# {'name': 'supto', 'versity': 'fau'}

# %%
dic['dept']='ICT'

# %%
dic
# Out:
# {'name': 'supto', 'versity': 'fau', 'dept': 'ICT'}

# %%
dic.update({'dept':'ai'})

# %%
dic
# Out:
# {'name': 'supto', 'versity': 'fau', 'dept': 'ai'}

# %%
dic.pop('versity')
# Out:
# 'fau'

# %%
dic
# Out:
# {'name': 'supto', 'dept': 'ai'}

# %%
del dic['name']

# %%
dic
# Out:
# {'dept': 'ai'}

# %%
#print all item
for x in dic:
    print(x)
# Out:
# dept

# %%
n=int(input())
d={}
for i in range(n):
    key=input()
    value=input()
    d[key]=value
    
print(d)
# Out:
#  3
#  name
#  shakil
#  dept
#  data science
#  sex
#  male
# {'name': 'shakil', 'dept': 'data science', 'sex': 'male'}
